# %%
from prettytable import PrettyTable

# %%
class Grammar:
    def __init__(self, grammar_str):
        self.grammar_str = '\n'.join(filter(None, grammar_str.splitlines()))
        self.grammar = {}
        self.start = None
        self.terminals = set()
        self.nonterminals = set()

        for production in list(filter(None, grammar_str.splitlines())):
            head, _, bodies = production.partition(' -> ')

            if not head.isupper():
                raise ValueError(
                    f'\'{head} -> {bodies}\': Head \'{head}\' is not capitalized to be treated as a nonterminal.')

            if not self.start:
                self.start = head

            self.grammar.setdefault(head, set())
            self.nonterminals.add(head)
            bodies = {tuple(body.split()) for body in ' '.join(bodies.split()).split('|')}

            for body in bodies:
                if '^' in body and body != ('^',):
                    raise ValueError(f'\'{head} -> {" ".join(body)}\': Null symbol \'^\' is not allowed here.')

                self.grammar[head].add(body)

                for symbol in body:
                    if not symbol.isupper() and symbol != '^':
                        self.terminals.add(symbol)
                    elif symbol.isupper():
                        self.nonterminals.add(symbol)

        self.symbols = self.terminals | self.nonterminals

# %%
grammar_file=open("grammar.txt","r")
G = Grammar(grammar_file.read())

# %%
def first_follow(G):
    def union(set_1, set_2):
        set_1_len = len(set_1)
        set_1 |= set_2

        return set_1_len != len(set_1)

    first = {symbol: set() for symbol in G.symbols}
    first.update((terminal, {terminal}) for terminal in G.terminals)
    follow = {symbol: set() for symbol in G.nonterminals}
    follow[G.start].add('$')

    while True:
        updated = False

        for head, bodies in G.grammar.items():
            for body in bodies:
                for symbol in body:
                    if symbol != '^':
                        updated |= union(first[head], first[symbol] - set('^'))

                        if '^' not in first[symbol]:
                            break
                    else:
                        updated |= union(first[head], set('^'))
                else:
                    updated |= union(first[head], set('^'))

                aux = follow[head]
                for symbol in reversed(body):
                    if symbol == '^':
                        continue
                    if symbol in follow:
                        updated |= union(follow[symbol], aux - set('^'))
                    if '^' in first[symbol]:
                        aux = aux | first[symbol]
                    else:
                        aux = first[symbol]

        if not updated:
            return first, follow

# %%
class SLRParser:
    def __init__(self, G):
        self.G_prime = Grammar(f"{G.start}' -> {G.start}\n{G.grammar_str}")
        self.max_G_prime_len = len(max(self.G_prime.grammar, key=len))
        self.G_indexed = []

        for head, bodies in self.G_prime.grammar.items():
            for body in bodies:
                self.G_indexed.append([head, body])

        self.first, self.follow = first_follow(self.G_prime)
        self.C = self.items(self.G_prime)
        self.action = list(self.G_prime.terminals) + ['$']
        self.goto = list(self.G_prime.nonterminals - {self.G_prime.start})
        self.parse_table_symbols = self.action + self.goto
        self.parse_table = self.construct_table()

    def CLOSURE(self, I):
        J = I

        while True:
            item_len = len(J)

            for head, bodies in J.copy().items():
                for body in bodies.copy():
                    if '.' in body[:-1]:
                        symbol_after_dot = body[body.index('.') + 1]

                        if symbol_after_dot in self.G_prime.nonterminals:
                            for G_body in self.G_prime.grammar[symbol_after_dot]:
                                J.setdefault(symbol_after_dot, set()).add(
                                    ('.',) if G_body == ('^',) else ('.',) + G_body)

            if item_len == len(J):
                return J

    def GOTO(self, I, X):
        goto = {}

        for head, bodies in I.items():
            for body in bodies:
                if '.' in body[:-1]:
                    dot_pos = body.index('.')

                    if body[dot_pos + 1] == X:
                        replaced_dot_body = body[:dot_pos] + (X, '.') + body[dot_pos + 2:]

                        for C_head, C_bodies in self.CLOSURE({head: {replaced_dot_body}}).items():
                            goto.setdefault(C_head, set()).update(C_bodies)

        return goto

    def items(self, G_prime):
        C = [self.CLOSURE({G_prime.start: {('.', G_prime.start[:-1])}})]

        while True:
            item_len = len(C)

            for I in C.copy():
                for X in G_prime.symbols:
                    goto = self.GOTO(I, X)

                    if goto and goto not in C:
                        C.append(goto)

            if item_len == len(C):
                print(C)
                return C

    def construct_table(self):
        parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

        for i, I in enumerate(self.C):
            for head, bodies in I.items():
                for body in bodies:
                    if '.' in body[:-1]:  # CASE 2 a
                        symbol_after_dot = body[body.index('.') + 1]

                        if symbol_after_dot in self.G_prime.terminals:
                            s = f's{self.C.index(self.GOTO(I, symbol_after_dot))}'

                            if s not in parse_table[i][symbol_after_dot]:
                                if 'r' in parse_table[i][symbol_after_dot]:
                                    parse_table[i][symbol_after_dot] += '/'

                                parse_table[i][symbol_after_dot] += s

                    elif body[-1] == '.' and head != self.G_prime.start:  # CASE 2 b
                        for j, (G_head, G_body) in enumerate(self.G_indexed):
                            if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                                for f in self.follow[head]:
                                    if parse_table[i][f]:
                                        parse_table[i][f] += '/'

                                    parse_table[i][f] += f'r{j}'

                                break

                    else:  # CASE 2 c
                        parse_table[i]['$'] = 'acc'

            for A in self.G_prime.nonterminals:  # CASE 3
                j = self.GOTO(I, A)

                if j in self.C:
                    parse_table[i][A] = self.C.index(j)

        return parse_table
    def print_augmented_grammar(self):
      def fprint(text, variable):
            print(f'{text:>12}: {", ".join(variable)}')
      print('AUGMENTED GRAMMAR:')

      for i, (head, body) in enumerate(self.G_indexed):
            print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_G_prime_len}} -> {" ".join(body)}')
            print()
      fprint('TERMINALS', self.G_prime.terminals)
      fprint('NONTERMINALS', self.G_prime.nonterminals)
      fprint('SYMBOLS', self.G_prime.symbols)
    def print_first_follow(self):
        print('\nFIRST:')
        for head in self.G_prime.grammar:
            print(f'{head:>{self.max_G_prime_len}} = {{ {", ".join(self.first[head])} }}')

        print('\nFOLLOW:')
        for head in self.G_prime.grammar:
            print(f'{head:>{self.max_G_prime_len}} = {{ {", ".join(self.follow[head])} }}')

    def print_all_sets(self):
        set_number=0;
        for i in self.C:
          print()
          print("I"+str(set_number))
          for h,b in i.items():
            prod=""
            for k in b:
              for f in k:
                prod+=" "+f
        
            print(h+"->",prod)
          set_number+=1
    def print_parsing_table(self):
        def fprint(text, variable):
            print(f'{text:>12}: {", ".join(variable)}')

        def print_line():
            print(f'+{("-" * width + "+") * (len(list(self.G_prime.symbols) + ["$"]))}')

        def symbols_width(symbols):
            return (width + 1) * len(symbols) - 1

        width = max(len(c) for c in {'ACTION'} | self.G_prime.symbols) + 2
        for r in range(len(self.C)):
            max_len = max(len(str(c)) for c in self.parse_table[r].values())
            if width < max_len + 2:
                width = max_len + 2

        print('\nPARSING TABLE:')
        print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
        print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
        print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
        print(f'|{"":^{width}}|', end=' ')

        for symbol in self.parse_table_symbols:
            print(f'{symbol:^{width - 1}}|', end=' ')

        print()
        print_line()

        for r in range(len(self.C)):
            print(f'|{r:^{width}}|', end=' ')

            for c in self.parse_table_symbols:
                print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

            print()

        print_line()
        print()

# %%
slr_parser = SLRParser(G)
slr_parser.print_augmented_grammar()
# Out:
# [{"STMT'": {('.', 'STMT')}, 'STMT': {('.', 'type', 'var', 'op', 'cp', 'begin', 'BODY', 'end')}}, {'STMT': {('type', '.', 'var', 'op', 'cp', 'begin', 'BODY', 'end')}}, {"STMT'": {('STMT', '.')}}, {'STMT': {('type', 'var', '.', 'op', 'cp', 'begin', 'BODY', 'end')}}, {'STMT': {('type', 'var', 'op', '.', 'cp', 'begin', 'BODY', 'end')}}, {'STMT': {('type', 'var', 'op', 'cp', '.', 'begin', 'BODY', 'end')}}, {'STMT': {('type', 'var', 'op', 'cp', 'begin', '.', 'BODY', 'end')}, 'BODY': {('.',), ('.', 'LOOP', 'BODY'), ('.', 'INITIALIZATIONLIST', 'BODY'), ('.', 'DECL', 'BODY')}, 'LOOP': {('.', 'for', 'op', 'EXPR', 'sc', 'var', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}, 'INITIALIZATIONLIST': {('.', 'var', 'eq', 'EXPR', 'sc', 'INITIALIZATIONLIST'), ('.', 'var', 'eq', 'EXPR', 'sc')}, 'DECL': {('.', 'type', 'sp', 'VARLIST', 'sc')}}, {'INITIALIZATIONLIST': {('var', '.', 'eq', 'EXPR', 'sc', 'INITIALIZATIONLIST'), ('var', '.', 'eq', 'EXPR', 'sc')}}, {'STMT': {('type', 'var', 'op', 'cp', 'begin', 'BODY', '.', 'end')}}, {'DECL': {('type', '.', 'sp', 'VARLIST', 'sc')}}, {'BODY': {('.', 'LOOP', 'BODY'), ('.', 'INITIALIZATIONLIST', 'BODY'), ('.',), ('INITIALIZATIONLIST', '.', 'BODY'), ('.', 'DECL', 'BODY')}}, {'BODY': {('.', 'LOOP', 'BODY'), ('.', 'INITIALIZATIONLIST', 'BODY'), ('.',), ('.', 'DECL', 'BODY'), ('DECL', '.', 'BODY')}}, {'LOOP': {('for', '.', 'op', 'EXPR', 'sc', 'var', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}}, {'BODY': {('.', 'LOOP', 'BODY'), ('.', 'INITIALIZATIONLIST', 'BODY'), ('.',), ('LOOP', '.', 'BODY'), ('.', 'DECL', 'BODY')}}, {'INITIALIZATIONLIST': {('var', 'eq', '.', 'EXPR', 'sc'), ('var', 'eq', '.', 'EXPR', 'sc', 'INITIALIZATIONLIST')}, 'EXPR': {('.', 'op', 'EXPR', 'cp'), ('.', 'num'), ('.', 'EXPR', 'oprt', 'EXPR'), ('.', 'var')}}, {'STMT': {('type', 'var', 'op', 'cp', 'begin', 'BODY', 'end', '.')}}, {'DECL': {('type', 'sp', '.', 'VARLIST', 'sc')}, 'VARLIST': {('.', 'var', 'VARLIST'), ('.', 'var')}}, {'BODY': {('INITIALIZATIONLIST', 'BODY', '.')}}, {'BODY': {('DECL', 'BODY', '.')}}, {'LOOP': {('for', 'op', '.', 'EXPR', 'sc', 'var', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}, 'EXPR': {('.', 'op', 'EXPR', 'cp'), ('.', 'EXPR', 'oprt', 'EXPR'), ('.', 'num'), ('.', 'var')}}, {'BODY': {('LOOP', 'BODY', '.')}}, {'EXPR': {('var', '.')}}, {'EXPR': {('num', '.')}}, {'EXPR': {('.', 'op', 'EXPR', 'cp'), ('op', '.', 'EXPR', 'cp'), ('.', 'num'), ('.', 'var'), ('.', 'EXPR', 'oprt', 'EXPR')}}, {'INITIALIZATIONLIST': {('var', 'eq', 'EXPR', '.', 'sc'), ('var', 'eq', 'EXPR', '.', 'sc', 'INITIALIZATIONLIST')}, 'EXPR': {('EXPR', '.', 'oprt', 'EXPR')}}, {'VARLIST': {('var', '.', 'VARLIST'), ('.', 'var'), ('var', '.'), ('.', 'var', 'VARLIST')}}, {'DECL': {('type', 'sp', 'VARLIST', '.', 'sc')}}, {'LOOP': {('for', 'op', 'EXPR', '.', 'sc', 'var', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}, 'EXPR': {('EXPR', '.', 'oprt', 'EXPR')}}, {'EXPR': {('EXPR', '.', 'oprt', 'EXPR'), ('op', 'EXPR', '.', 'cp')}}, {'EXPR': {('.', 'op', 'EXPR', 'cp'), ('EXPR', 'oprt', '.', 'EXPR'), ('.', 'num'), ('.', 'var'), ('.', 'EXPR', 'oprt', 'EXPR')}}, {'INITIALIZATIONLIST': {('.', 'var', 'eq', 'EXPR', 'sc', 'INITIALIZATIONLIST'), ('.', 'var', 'eq', 'EXPR', 'sc'), ('var', 'eq', 'EXPR', 'sc', '.'), ('var', 'eq', 'EXPR', 'sc', '.', 'INITIALIZATIONLIST')}}, {'VARLIST': {('var', 'VARLIST', '.')}}, {'DECL': {('type', 'sp', 'VARLIST', 'sc', '.')}}, {'LOOP': {('for', 'op', 'EXPR', 'sc', '.', 'var', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}}, {'EXPR': {('op', 'EXPR', 'cp', '.')}}, {'EXPR': {('EXPR', 'oprt', 'EXPR', '.'), ('EXPR', '.', 'oprt', 'EXPR')}}, {'INITIALIZATIONLIST': {('var', 'eq', 'EXPR', 'sc', 'INITIALIZATIONLIST', '.')}}, {'LOOP': {('for', 'op', 'EXPR', 'sc', 'var', '.', 'relop', 'var', 'sc', 'INITIALIZATIONLIST', 'cp', 'begin', 'BODY', 'end')}}, {'LOOP': {('for', 'op', 'EXPR', 'sc', 'var', 'relop', '.', 'var', ' ...
# AUGMENTED GRAMMAR:
#  0:              STMT' -> STMT
#
#  1:               STMT -> type var op cp begin BODY end
#
#  2:               BODY -> INITIALIZATIONLIST BODY
#
#  3:               BODY -> LOOP BODY
#
#  4:               BODY -> ^
#
#  5:               BODY -> DECL BODY
#
#  6:               DECL -> type sp VARLIST sc
#
#  7:            VARLIST -> var VARLIST
#
#  8:            VARLIST -> var
#
#  9:               LOOP -> for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end
#
# 10: INITIALIZATIONLIST -> var eq EXPR sc
#
# 11: INITIALIZATIONLIST -> var eq EXPR sc INITIALIZATIONLIST
#
# 12:               EXPR -> EXPR oprt EXPR
#
# 13:               EXPR -> num
#
# 14:               EXPR -> op EXPR cp
#
# 15:               EXPR -> var
#
#    TERMINALS: cp, sp, for, op, var, sc, oprt, eq, num, type, relop, end, begin
# NONTERMINALS: BODY, EXPR, INITIALIZATIONLIST, STMT, STMT', DECL, VARLIST, LOOP
#      SYMBOLS: cp, oprt, var, BODY, type, INITIALIZATIONLIST, STMT, relop, STMT', DECL, end, VARLIST, num, sp, for, op, sc, EXPR, begin, LOOP, eq

# %%
slr_parser.print_first_follow()
# Out:
# FIRST:
#              STMT' = { type }
#               STMT = { type }
#               BODY = { type, ^, for, var }
#               DECL = { type }
#            VARLIST = { var }
#               LOOP = { for }
# INITIALIZATIONLIST = { var }
#               EXPR = { num, op, var }
#
# FOLLOW:
#              STMT' = { $ }
#               STMT = { $ }
#               BODY = { end }
#               DECL = { type, end, for, var }
#            VARLIST = { sc }
#               LOOP = { type, end, for, var }
# INITIALIZATIONLIST = { cp, for, var, type, end }
#               EXPR = { cp, oprt, sc }

# %%
slr_parser.print_all_sets()
# Out:
# I0
# STMT'->  . STMT
# STMT->  . type var op cp begin BODY end
#
# I1
# STMT->  type . var op cp begin BODY end
#
# I2
# STMT'->  STMT .
#
# I3
# STMT->  type var . op cp begin BODY end
#
# I4
# STMT->  type var op . cp begin BODY end
#
# I5
# STMT->  type var op cp . begin BODY end
#
# I6
# STMT->  type var op cp begin . BODY end
# BODY->  . . LOOP BODY . INITIALIZATIONLIST BODY . DECL BODY
# LOOP->  . for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end
# INITIALIZATIONLIST->  . var eq EXPR sc INITIALIZATIONLIST . var eq EXPR sc
# DECL->  . type sp VARLIST sc
#
# I7
# INITIALIZATIONLIST->  var . eq EXPR sc INITIALIZATIONLIST var . eq EXPR sc
#
# I8
# STMT->  type var op cp begin BODY . end
#
# I9
# DECL->  type . sp VARLIST sc
#
# I10
# BODY->  . LOOP BODY . INITIALIZATIONLIST BODY . INITIALIZATIONLIST . BODY . DECL BODY
#
# I11
# BODY->  . LOOP BODY . INITIALIZATIONLIST BODY . . DECL BODY DECL . BODY
#
# I12
# LOOP->  for . op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end
#
# I13
# BODY->  . LOOP BODY . INITIALIZATIONLIST BODY . LOOP . BODY . DECL BODY
#
# I14
# INITIALIZATIONLIST->  var eq . EXPR sc var eq . EXPR sc INITIALIZATIONLIST
# EXPR->  . op EXPR cp . num . EXPR oprt EXPR . var
#
# I15
# STMT->  type var op cp begin BODY end .
#
# I16
# DECL->  type sp . VARLIST sc
# VARLIST->  . var VARLIST . var
#
# I17
# BODY->  INITIALIZATIONLIST BODY .
#
# I18
# BODY->  DECL BODY .
#
# I19
# LOOP->  for op . EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end
# EXPR->  . op EXPR cp . EXPR oprt EXPR . num . var
#
# I20
# BODY->  LOOP BODY .
#
# I21
# EXPR->  var .
#
# I22
# EXPR->  num .
#
# I23
# EXPR->  . op EXPR cp op . EXPR cp . num . var . EXPR oprt EXPR
#
# I24
# INITIALIZATIONLIST->  var eq EXPR . sc var eq EXPR . sc INITIALIZATIONLIST
# EXPR->  EXPR . oprt EXPR
#
# I25
# VARLIST->  var . VARLIST . var var . . var VARLIST
#
# I26
# DECL->  type sp VARLIST . sc
#
# I27
# LOOP->  for op EXPR . sc var relop var sc INITIALIZATIONLIST cp begin BODY end
# EXPR->  EXPR . oprt EXPR
#
# I28
# EXPR->  EXPR . oprt EXPR op EXPR . cp
#
# I29
# EXPR->  . op EXPR cp EXPR oprt . EXPR . num . var . EXPR oprt EXPR
#
# I30
# INITIALIZATIONLIST->  . var eq EXPR sc INITIALIZATIONLIST . var eq EXPR sc var eq EXPR sc . var eq EXPR sc . INITIALIZATIONLIST
#
# I31
# VARLIST->  var VARLIST .
#
# I32
# DECL->  type sp VARLIST sc .
#
# I33
# LOOP->  for op EXPR sc . var relop var sc INITIALIZATIONLIST cp begin BODY end
#
# I34
# EXPR->  op EXPR cp .
#
# I35
# EXPR->  EXPR oprt EXPR . EXPR . oprt EXPR
#
# I36
# INITIALIZATIONLIST->  var eq EXPR sc INITIALIZATIONLIST .
#
# I37
# LOOP->  for op EXPR sc var . relop var sc INITIALIZATIONLIST cp begin BODY end
#
# I38
# LOOP->  for op EXPR sc var relop . var sc INITIALIZATIONLIST cp begin BODY end
#
# I39
# LOOP->  for op EXPR sc var relop var . sc INITIALIZATIONLIST cp begin BODY end
#
# I40
# LOOP->  for op EXPR sc var relop var sc . INITIALIZATIONLIST cp begin BODY end
# INITIALIZATIONLIST->  . var eq EXPR sc INITIALIZATIONLIST . var eq EXPR sc
#
# I41
# LOOP->  for op EXPR sc var relop var sc INITIALIZATIONLIST . cp begin BODY end
#
# I42
# LOOP->  for op EXPR sc var relop var sc INITIALIZATIONLIST cp . begin BODY end
#
# I43
# LOOP->  for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin . BODY end . for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end
# BODY->  . . LOOP BODY . INITIALIZATIONLIST BODY . DECL BODY
# INITIALIZATIONLIST->  . var eq EXPR sc INITIALIZATIONLIST . var eq EXPR sc
# DECL->  . type sp VARLIST sc
#
# I44
# LOOP->  for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY . end
#
# I45
# LOOP->  for op EXPR sc var relop var sc INITIALIZATIONLIST cp begin BODY end .

# %%
slr_parser.print_parsing_table()
# Out:
# PARSING TABLE:
# +--------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------+
# |                    |                                                                                                                                               ACTION                                                                                                                                                |                                                                       GOTO                                                                       |
# |       STATE        +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                    |         cp         |         sp         |         for        |         op         |         var        |         sc         |        oprt        |         eq         |         num        |        type        |        relop       |         end        |        begin       |          $         |        BODY        |        EXPR        | INITIALIZATIONLIST |        STMT        |        DECL        |       VARLIST      |        LOOP        |
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |         0          |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s1         |                    |                    |                    |                    |                    |                    |                    |          2         |                    |                    |                    |
# |         1          |                    |                    |                    |                    |         s3         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         2          |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         acc        |                    |                    |                    |                    |                    |                    |                    |
# |         3          |                    |                    |                    |         s4         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         4          |         s5         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         5          |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s6         |                    |                    |                    |                    |                    |                    |                    |                    |
# |         6          |                    |                    |         s12        |                    |         s7         |                    |                    |                    |                    |         s9         |                    |         r4         |                    |                    |          8         |                    |         10         |                    |         11         |                    |         13         |
# |         7          |                    |                    |                    |                    |                    |                    |                    |         s14        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         8          |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s15        |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         9          |                    |         s16        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         10         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r4         |                    |                    |         17         |                    |         10         |                    |         11         |                    |         13         |
# |         11         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r4         |                    |                    |         18         |                    |         10         |                    |         11         |                    |         13         |
# |         12         |                    |                    |                    |         s19        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         13         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r4         |                    |                    |         20         |                    |         10         |                    |         11         |                    |         13         |
# |         14         |                    |                    |                    |         s23        |         s21        |                    |                    |                    |         s22        |                    |                    |                    |                    |                    |                    |         24         |                    |                    |                    |                    |                    |
# |         15         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r1         |                    |                    |                    |                    |                    |                    |                    |
# |         16         |                    |                    |                    |                    |         s25        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         26         |                    |
# |         17         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r2         |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         18         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r5         |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         19         |                    |                    |                    |         s23        |         s21        |                    |                    |                    |         s22        |                    |                    |                    |                    |                    |                    |         27         |                    |                    |                    |                    |                    |
# |         20         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         r3         |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         21         |         r15        |                    |                    |                    |                    |         r15        |         r15        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         22         |         r13        |                    |                    |                    |                    |         r13        |         r13        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         23         |                    |                    |                    |         s23        |         s21        |                    |                    |                    |         s22        |                    |                    |                    |                    |                    |                    |         28         |                    |                    |                    |                    |                    |
# |         24         |                    |                    |                    |                    |                    |         s30        |         s29        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         25         |                    |                    |                    |                    |         s25        |         r8         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         31         |                    |
# |         26         |                    |                    |                    |                    |                    |         s32        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         27         |                    |                    |                    |                    |                    |         s33        |         s29        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         28         |         s34        |                    |                    |                    |                    |                    |         s29        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         29         |                    |                    |                    |         s23        |         s21        |                    |                    |                    |         s22        |                    |                    |                    |                    |                    |                    |         35         |                    |                    |                    |                    |                    |
# |         30         |         r10        |                    |         r10        |                    |       s7/r10       |                    |                    |                    |                    |         r10        |                    |         r10        |                    |                    |                    |                    |         36         |                    |                    |                    |                    |
# |         31         |                    |                    |                    |                    |                    |         r7         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         32         |                    |                    |         r6         |                    |         r6         |                    |                    |                    |                    |         r6         |                    |         r6         |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         33         |                    |                    |                    |                    |         s37        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         34         |         r14        |                    |                    |                    |                    |         r14        |         r14        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         35         |         r12        |                    |                    |                    |                    |         r12        |       r12/s29      |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         36         |         r11        |                    |         r11        |                    |         r11        |                    |                    |                    |                    |         r11        |                    |         r11        |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         37         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s38        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         38         |                    |                    |                    |                    |         s39        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         39         |                    |                    |                    |                    |                    |         s40        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         40         |                    |                    |                    |                    |         s7         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         41         |                    |                    |                    |                    |
# |         41         |         s42        |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         42         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s43        |                    |                    |                    |                    |                    |                    |                    |                    |
# |         43         |                    |                    |         s12        |                    |         s7         |                    |                    |                    |                    |         s9         |                    |         r4         |                    |                    |         44         |                    |         10         |                    |         11         |                    |         13         |
# |         44         |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |                    |         s45        |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# |         45         |                    |                    |         r9         |                    |         r9         |                    |                    |                    |                    |         r9         |                    |         r9         |                    |                    |                    |                    |                    |                    |                    |                    |                    |
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
